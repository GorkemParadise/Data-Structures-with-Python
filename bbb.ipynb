# %%
arr = [5,6,7,8,9,10]

# %%
def sort(arr): #arr dizisi sort mu değil mi kontrol etmek istiyorum
    for i in range(len(arr)-1):
        if arr[i] > arr[i+1]:
            return False
    return True

# %%
sort(arr)
# Out:
# True
