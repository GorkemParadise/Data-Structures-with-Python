# %%
from re import A


arr = [80, 20, 10, 30, 60, 50, 70, 40]

for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1
    while key < arr[j] and j > -1:
        arr[j+1] = arr[j]
        arr[j] = key
        j -=1

print(arr)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]
